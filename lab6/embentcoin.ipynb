# %%
import numpy as np
import csv as csv

# %%
def coin_em(rolls, theta_1=None, theta_2=None,theta_3=None,theta_4=None,theta_5=None,theta_6=None,theta_7=None,theta_8=None,theta_9=None,theta_10=None, maxiter=10):
    # Initial Guess
    theta_1 = theta_1 or random.random()
    theta_2 = theta_2 or random.random()
    theta_3 = theta_3 or random.random()
    theta_4 = theta_4 or random.random()
    theta_5 = theta_5 or random.random()
    theta_6 = theta_6 or random.random()
    theta_7 = theta_7 or random.random()
    theta_8 = theta_8 or random.random()
    theta_9 = theta_9 or random.random()
    theta_10 = theta_10 or random.random()
    
    thetas = [(theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10)]
    # Iterate
    for c in range(maxiter):
        print("#%d:\t%0.2f %0.2f %0.2f %0.2f %0.2f %0.2f %0.2f %0.2f %0.2f %0.2f" % (c, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10))
        heads_1, tails_1, heads_2, tails_2, heads_3, tails_3, heads_4, tails_4, heads_5, tails_5, heads_6, tails_6, heads_7, tails_7, heads_8, tails_8, heads_9, tails_9, heads_10, tails_10 = e_step(rolls, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10)
        theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10 = m_step(heads_1, tails_1, heads_2, tails_2, heads_3, tails_3, heads_4, tails_4, heads_5, tails_5, heads_6, tails_6, heads_7, tails_7, heads_8, tails_8, heads_9, tails_9, heads_10, tails_10)
        
    thetas.append((theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10))
    return thetas, (theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10)

# %%
def e_step(rolls, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10):
    """Produce the expected value for heads_1, tails_1, heads_2, tails_2, heads_3, tails_3, heads_4, tails_4, heads_5, tails_5, heads_6, tails_6, heads_7, tails_7, heads_8, tails_8, heads_9, tails_9, heads_10, tails_10 
    over the rolls given the coin biases"""
    
    heads_1, tails_1 = 0,0
    heads_2, tails_2 = 0,0
    heads_3, tails_3 = 0,0
    heads_4, tails_4 = 0,0
    heads_5, tails_5 = 0,0
    heads_6, tails_6 = 0,0
    heads_7, tails_7 = 0,0
    heads_8, tails_8 = 0,0
    heads_9, tails_9 = 0,0
    heads_10, tails_10 = 0,0
    
    for trial in rolls:
        likelihood_1 = coin_likelihood(trial, theta_1)
        likelihood_2 = coin_likelihood(trial, theta_2)
        likelihood_3 = coin_likelihood(trial, theta_3)
        likelihood_4 = coin_likelihood(trial, theta_4)
        likelihood_5 = coin_likelihood(trial, theta_5)
        likelihood_6 = coin_likelihood(trial, theta_6)
        likelihood_7 = coin_likelihood(trial, theta_7)
        likelihood_8 = coin_likelihood(trial, theta_8)
        likelihood_9 = coin_likelihood(trial, theta_9)
        likelihood_10 = coin_likelihood(trial, theta_10)
        
        p_1 = likelihood_1 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        p_2 = likelihood_2 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        p_3 = likelihood_3 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        p_4 = likelihood_4 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        p_5 = likelihood_5 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        p_6 = likelihood_6 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        p_7 = likelihood_7 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        p_8 = likelihood_8 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        p_9 = likelihood_9 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        p_10 = likelihood_10 / (likelihood_1 + likelihood_2 + likelihood_3 + likelihood_4 + likelihood_5 + likelihood_6 + likelihood_7 + likelihood_8 + likelihood_9 + likelihood_10)
        
        heads_1 += p_1 * trial.count("H")
        tails_1 += p_1 * trial.count("T")
        heads_2 += p_2 * trial.count("H")
        tails_2 += p_2 * trial.count("T") 
        heads_3 += p_3 * trial.count("H")
        tails_3 += p_3 * trial.count("T")
        heads_4 += p_4 * trial.count("H")
        tails_4 += p_4 * trial.count("T")
        heads_5 += p_5 * trial.count("H")
        tails_5 += p_5 * trial.count("T")
        heads_6 += p_6 * trial.count("H")
        tails_6 += p_6 * trial.count("T")
        heads_7 += p_7 * trial.count("H")
        tails_7 += p_7 * trial.count("T")
        heads_8 += p_8 * trial.count("H")
        tails_8 += p_8 * trial.count("T")
        heads_9 += p_9 * trial.count("H")
        tails_9 += p_9 * trial.count("T")
        heads_10 += p_10 * trial.count("H")
        tails_10 += p_10 * trial.count("T")
        
    return heads_1, tails_1, heads_2, tails_2, heads_3, tails_3, heads_4, tails_4, heads_5, tails_5, heads_6, tails_6, heads_7, tails_7, heads_8, tails_8, heads_9, tails_9, heads_10, tails_10

# %%
def m_step(heads_1, tails_1, heads_2, tails_2, heads_3, tails_3, heads_4, tails_4, heads_5, tails_5, heads_6, tails_6, heads_7, tails_7, heads_8, tails_8, heads_9, tails_9, heads_10, tails_10):
    """Produce the values for theta that maximize the expected number of heads/tails"""

    theta_1 = heads_1 / (heads_1 + tails_1)
    theta_2 = heads_2 / (heads_2 + tails_2)
    theta_3 = heads_3 / (heads_3 + tails_3)
    theta_4 = heads_4 / (heads_4 + tails_4)
    theta_5 = heads_5 / (heads_5 + tails_5)
    theta_6 = heads_6 / (heads_6 + tails_6)
    theta_7 = heads_7 / (heads_7 + tails_7)
    theta_8 = heads_8 / (heads_8 + tails_8)
    theta_9 = heads_9 / (heads_9 + tails_9)
    theta_10 = heads_10 / (heads_10 + tails_10)
    
    return theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10

# %%
def coin_likelihood(roll, bias):
    # P(X | Z, theta)
    numHeads = roll.count("H")
    flips = len(roll)
    return pow(bias, numHeads) * pow(1-bias, flips-numHeads)

# %% [markdown]
# The original `two_bent_coins.csv` and `2020_ten_bent_coins.csv` have been slightly modified for the below functions. An additional row was included at the top of each file as a column header.
#
# Eg. the following numbering was included in `two_bent_coins.csv`
#
#  ![image.png](data:image/png;base64,...)
#
#  Using the original csv for below two cells could produce errors or unexpected outputs.

# %%
# with open('two_bent_coins.csv', mode='r') as csv_file:
#     csv_reader = csv.DictReader(csv_file)
#     rolls = []
#     for row in csv_reader:
#       trial=""
#       for index in range(1,21):
#         if row[str(index)] == "1":
#           trial+="H"
#         else:
#           trial+="T"
#       rolls.append(trial)
#     print(rolls)
# # Theta values borrowed from the matlab script embentcoinsol.m
# thetas, _ = coin_em(rolls, 0.2, 0.5, maxiter=10)

# %%
with open('2020_ten_bent_coins.csv', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    rolls = []
    for row in csv_reader:
      trial=""
      for index in range(1,101):
        if row[str(index)] == "1":
          trial+="H"
        else:
          trial+="T"
      rolls.append(trial)
    print(rolls)
thetas, _ = coin_em(rolls, 0.45, 0.39, 0.52, 0.55, 0.62, 0.53, 0.47, 0.35, 0.71, 0.50, maxiter=50)
# Out:
# ['HHHHHHHHHHHHHHHHHHHTHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTHHHHHHHTHHHHHHHHHHHTHHHHHHHHHHHHH', 'TTTTTTHTTHTHHHTTTTTHTHHHTTTTTTHTHTTTHTTTTHTHTTTTTHTTHHTTTTHTHTTTTTTTTHTTHTTTTTTHHTTTHTTTTTHTTTTTHTTT', 'HTHHTHTTTHHHHTHTTTHHTTHTTHHTHHTTTHTHTHHTTTTHTTTTTHHTTTTHHTTHTHTTHHTHTHTTTHTTHTTTTTTTTTTTHHHHHTTTHHTT', 'TTTTTTTTHTTTTTTHTTHHTTTTHTTTTTHTTHTTTTHTHTTTTTTHHTTTHHTTTTTTTTTTTTTTTTTTHTTTHTTTHTTTHTTTTHTHTHTTTTHT', 'HTTHTHTTTHTTHTHTTTTHHHHTTHTTTTTTTTHTHTHHTTHTTTTTTHHHHHHHHTTHTTHTTTHTTHHTTTTHHTTHTTTTTTHHHTHHHTTTHHHH', 'HHHHHTHHHHHHHHHHHHHHHTHHHHHHTHHHHHTHTHHHHHHHTHHHTHHHHHHTHHHHHHHHHHHHHTHHHHHHHHHHHHHHHHHHHHHHHTHHHTHH', 'TTTTHTHTTTHTTTTTHHTHTHHHTHTHTTTHTTTTTHTHHHHHTHTHTTTTHTHTTHHTTTTHTHTHHTHTHHTTTHHTTHHHTTHTHHTHTHTHTHTH', 'HTTHTTHHHHTTHTHTTHTHTTHHHTTTTTHHTHHTTTTHTTTTTTTTHTHTTTTTTTHTTTHTTTHTTHTTTTHTTHHTTTTTTTHTTHHTTHTTTTTT', 'HHHTTHTTHHTTHHTTTTTTHTTTHHTHTHHHTTTHHTHTTTTTTHHTTHTHHTTHTTHTTTHTTTHHTHHHTHHTHHHHHHHHHHTTHHTTHHHTTHTT', 'TTTTTHTTTTTTTTTTTTHTTTTTTHTTTTTTTTTTTTTTTTTTTTHTTTTTHTTTTTTT
# ...
